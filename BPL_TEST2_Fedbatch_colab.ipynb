# %% [markdown]
# <a href="https://colab.research.google.com/github/janpeter19/BPL_TEST2_Fedbatch/blob/main/BPL_TEST2_Fedbatch_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BPL_TEST2_Fedbatch script with PyFMI
#
# The key library PyFMI is installed.
#
# After the installation a small application BPL_TEST2_Fedbatch is loaded and run. You can continue with this example if you like.

# %%
# !lsb_release -a # Actual VM Ubuntu version used by Google
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.3 LTS
# Release:	22.04
# Codename:	jammy

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# !python --version

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py311_24.11.1-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py311_24.11.1-0-Linux-x86_64.sh
# !bash ./Miniconda3-py311_24.11.1-0-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.11/site-packages/')

# %%
# !conda update -n base -c defaults conda --yes
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.1.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |  py310h6a678d5_9         356 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     certifi-2024.12.14         |  py310h06a4308_0         160 KB
#     cffi-1.17.1                |  py310h1fdaa30_1         251 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     conda-package-handling-2.4.0|  py310h06a4308_0         272 KB
#     conda-package-streaming-0.11.0|  py310h06a4308_0          30 KB
#     cryptography-43.0.3        |  py310h7825ff9_1         1.5 MB
#     idna-3.7                   |  py310h06a4308_0         130 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     lz4-c-1.9.4                |       h6a678d5_1         156 KB
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     pluggy-1.5.0               |  py310h06a4308_0          37 KB
#     pycosat-0.6.6              |  py310h5eee18b_2          88 KB
#     pyopenssl-24.2.1           |  py310h06a4308_0          97 KB
#     python-3.10.16             |       he870216_1        26.9 MB
#     requests-2.32.3            |  py310h06a4308_1         101 KB
#     ruamel.yaml.clib-0.2.8     |  py310h5eee18b_0         157 KB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     toolz-1.0.0                |  py310h06a4308_0         109 KB
#     tqdm-4.66.5                |  py310h2f386ee_0         134 KB
#     tzdata-2025a               |       h04d1e81_0         117 KB
#     urllib3-2.3.0              |  py310h06a4308_0         190 KB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     zstandard-0.23.0           |  py310h2c38b39_1         431 KB
#     zstd-1.5.6                 |       hc292b87_0         664 KB
#     ------------------------------------------------------------
#                                            Total:        43.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      pkgs/main/linux-64::brotli-python-1.0.9-py310h6a678d5_9
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   zstd               pkgs/main/linux-64::zstd-1.5.6-hc292b87_0
#
# The following packages will be REMOVED:
#
#   brotlipy-0.7.0-py310h7f8727e_1002
#
# The following packages will be UPDATED:
#
#   bzip2                                    1.0.8-h7b6447c_0 --> 1.0.8-h5eee18b_6
#   ca-certificates                     2023.01.10-h06a4308_0 --> 2024.12.31-h06a4308_0
#   certifi                         2022.12.7-py310h06a4308_0 --> 2024.12.14-py310h06a4308_0
#   cffi                               1.15.1-py310h5eee18b_3 --> 1.17.1-py310h1fdaa30_1
#   charset-normalizer                     2.0.4-pyhd3eb1b0_0 --> 3.3.2-pyhd3eb1b0_0
#   conda-package-han~                  2.0.2-py310h06a4308_0 --> 2.4.0-py310h06a4308_0
#   conda-package-str~                  0.7.0-py310h06a4308_0 --> 0.11.0-py310h06a4308_0
#   cryptography                       38.0.4-py310h9ce1e76_0 --> 43.0.3-py310h7825ff9_1
#   idna                                  3.4-py310h06a4308_0 --> 3.7-py310h06a4308_0
#   ld_impl_linux-64                          2.38-h1181459_1 --> 2.40-h12ee557_0
#   libffi                                   3.4.2-h6a678d5_6 --> 3.4.4-h6a678d5_1
#   openssl                                 1.1.1s-h7f8727e_0 --> 3.0.15-h5eee18b_0
#   pluggy                              1.0.0-py310h06a4308_1 --> 1.5.0-py310h06a4308_0
#   pycosat                             0.6.4-py310h5eee18b_0 --> 0.6.6-py310h5eee18b_2
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-py~ --> pkgs/main/linux-64::pyopenssl-24.2.1-py310h06a4308_0
#   python                                  3.10.9-h7a1cb2a_0 --> 3.10.16-he870216_1
#   requests                           2.28.1-py310h06a4308_0 --> 2.32.3-py310h06a4308_1
#   ruamel.yaml.clib                    0.2.6-py310h5eee18b_1 --> 0.2.8-py310h5eee18b_0
#   sqlite                                  3.40.1-h5082296_0 --> 3.45.3-h5eee18b_0
#   tk                                      8.6.12-h1ccaba5_0 --> 8.6.14-h39e8969_0
#   toolz                              0.12.0-py310h06a4308_0 --> 1.0.0-py310h06a4308_0
#   tqdm                               4.64.1-py310h06a4308_0 --> 4.66.5-py310h2f386ee_0
#   tzdata                                   2022g-h04d1e81_0 --> 2025a-h04d1e81_0
#   urllib3                           1.26.14-py310h06a4308_0 --> 2.3.0-py310h06a4308_0
#   xz                                      5.2.10-h5eee18b_1 --> 5.4.6-h5eee18b_1
#   zlib                                    1.2.13-h5eee18b_0 --> 1.2.13-h5eee18b_1
#   zstandard                          0.18.0-py310h5eee18b_0 --> 0.23.0-py310h2c38b39_1
#
#
#
# Downloading and Extracting Packages
# certifi-2024.12.14   | 160 KB    | :   0% 0/1 [00:00<?, ?it/s]
# cryptography-43.0.3  | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# requests-2.32.3      | 101 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# toolz-1.0.0          | 109 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# bzip2-1.0.8          | 262 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# zstd-1.5.6           | 664 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# conda-package-stream | 30 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# brotli-python-1.0.9  | 356 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# idna-3.7             | 130 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# tqdm-4.66.5          | 134 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# urllib3-2.3.0        | 190 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 156 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# pluggy-1.5.0         | 37 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 251 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 643 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.12.14   | 160 KB    | :  10% 0.0998488615864658/1 [00:00<00:01,  1.13s/it]
# cryptography-43.0.3  | 1.5 MB    | :   1% 0.01068206386027777/1 [00:00<00:10, 10.91s/it]
#
# requests-2.32.3      | 101 KB    | :  16% 0.15884126537853743/1 [00:00<00:00,  1.29it/s]
#
#
# toolz-1.0.0          | 109 KB    | :  15% 0.1466943628679894/1 [00:00<00:00,  1.13it/s]
#
#
#
# bzip2-1.0.8          | 262 KB    | :   6% 0.06104685823297961/1 [00:00<00:02,  2.19s/it]
#
#
#
#
#
# conda-package-stream | 30 KB     | :  53% 0.5335070009768805/1 [00:00<00:00,  2.81it/s]
#
#
#
#
# zstd-1.5.6           | 664 KB    | :   2% 0.02408420062327277/1 [00:00<00:07,  7.90s/it]
#
#
#
#
#
#
#
# idna-3.7             | 130 KB    | :  12% 0.12352324731036875/1 [00:00<00:01,  1.67s/it]
#
#
#
#
#
#
# brotli-python-1.0.9  | 356 KB    | :   4% 0.044952205357828776/1 [00:00<00:04,  4.82s/it]
#
#
#
#
#
#
#
#
# tqdm-4.66.5          | 134 KB    | :  12% 0.11935514420380124/1 [00:00<00:01,  2.02s/it]
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 156 KB    | :  10% 0.10272422332988496/1 [00:00<00:02,  2.47s/it]
#
#
#
#
#
#
#
#
#
# urllib3-2.3.0        | 190 KB    | :   8% 0.0844040100147336/1 [00:00<00:02,  3.05s/it]
#
# requests-2.32.3      | 101 KB    | : 100% 1.0/1 [00:00<00:00,  3.82it/s]
#
# certifi-2024.12.14   | 160 KB    | : 100% 1.0/1 [00:00<00:00,  3.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | :  14% 0.13631182661508381/1 [00:00<00:01,  2.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 251 KB    | :   6% 0.06365289281884723/1 [00:00<00:04,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :   0% 0.0005819339279804907/1 [00:00<08:37, 517.84s/it]
#
#
#
#
#
#
#
#
#
#
#
# pluggy-1.5.0         | 37 KB     | :  43% 0.43039903328342133/1 [00:00<00:00,  1.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 643 KB    | :   2% 0.02486413806395413/1 [00:00<00:12, 12.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | :  11% 0.11323440988036575/1 [00:00<00:02,  2.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     | :  18% 0.18113274297148796/1 [00:00<00:01,  1.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :   5% 0.04655471423843926/1 [00:00<00:06,  6.76s/it]
#
#
#
# bzip2-1.0.8          | 262 KB    | : 100% 1.0/1 [00:00<00:00,  2.34it/s]
#
#
#
# bzip2-1.0.8          | 262 KB    | : 100% 1.0/1 [00:00<00:00,  2.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :   8% 0.07914301420534674/1 [00:00<00:04,  4.93s/it]
#
#
# toolz-1.0.0          | 109 KB    | : 100% 1.0/1 [00:00<00:00,  1.76it/s]
#
#
# toolz-1.0.0          | 109 KB    | : 100% 1.0/1 [00:00<00:00,  1.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  13% 0.12802546415570795/1 [00:00<00:03,  3.50s/it]
#
#
#
#
#
# conda-package-stream | 30 KB     | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
#
#
#
#
#
# conda-package-stream | 30 KB     | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  18% 0.1809814516019326/1 [00:00<00:02,  2.80s/it]
#
#
#
#
#
#
#
# idna-3.7             | 130 KB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
#
#
#
#
#
#
#
# idna-3.7             | 130 KB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  25% 0.24790385331968906/1 [00:00<00:01,  2.22s/it]
#
#
#
#
#
#
# brotli-python-1.0.9  | 356 KB    | : 100% 1.0/1 [00:00<00:00,  1.26it/s]
#
#
#
#
#
#
# brotli-python-1.0.9  | 356 KB    | : 100% 1.0/1 [00:00<00:00,  1.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  35% 0.3549796960680993/1 [00:00<00:01,  1.57s/it]
#
#
#
#
# zstd-1.5.6           | 664 KB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
#
#
#
#
# zstd-1.5.6           | 664 KB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  50% 0.5010451119912025/1 [00:01<00:00,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  60% 0.6040474172437493/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
# tqdm-4.66.5          | 134 KB    | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
#
#
#
#
#
#
#
#
# tqdm-4.66.5          | 134 KB    | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 156 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 156 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  70% 0.7006484492885108/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  80% 0.7955036795493308/1 [00:01<00:00,  1.11s/it]
#
#
#
#
#
#
#
#
#
# urllib3-2.3.0        | 190 KB    | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
#
# urllib3-2.3.0        | 190 KB    | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
# cryptography-43.0.3  | 1.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.33s/it]
# cryptography-43.0.3  | 1.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# pluggy-1.5.0         | 37 KB     | : 100% 1.0/1 [00:01<00:00,  1.50s/it]
#
#
#
#
#
#
#
#
#
#
#
# pluggy-1.5.0         | 37 KB     | : 100% 1.0/1 [00:01<00:00,  1.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  89% 0.8880311740982288/1 [00:01<00:00,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 251 KB    | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 251 KB    | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | :  99% 0.9881238097108732/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | : 100% 1.0/1 [00:01<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | : 100% 1.0/1 [00:01<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     | : 100% 1.0/1 [00:02<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     | : 100% 1.0/1 [00:02<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 643 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 643 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 26.9 MB   | : 100% 1.0/1 [00:04<00:00,  1.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !conda --version
# !python --version
# Out:
# conda 23.1.0
# Python 3.10.16

# %%
# !conda config --set channel_priority strict

# %%
# !conda install -c conda-forge pyfmi --yes # Install the key package
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.1.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pyfmi
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     assimulo-3.6.0             |  py310hde9f7ad_0         1.0 MB  conda-forge
#     ca-certificates-2024.12.14 |       hbcca054_0         153 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     fmilib-2.4.1               |       hac33072_1         383 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     libamd-3.3.3               |   ss783_h889e182          47 KB  conda-forge
#     libblas-3.9.0              |26_linux64_openblas          16 KB  conda-forge
#     libbtf-2.3.2               |   ss783_h2377355          26 KB  conda-forge
#     libcamd-3.3.3              |   ss783_h2377355          43 KB  conda-forge
#     libcblas-3.9.0             |26_linux64_openblas          16 KB  conda-forge
#     libccolamd-3.3.4           |   ss783_h2377355          40 KB  conda-forge
#     libcholmod-5.3.0           |   ss783_h3fa60b6         971 KB  conda-forge
#     libcolamd-3.3.4            |   ss783_h2377355          32 KB  conda-forge
#     libcxsparse-4.4.1          |   ss783_h2377355         112 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_1          53 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_1          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hd5240d6_1         1.4 MB  conda-forge
#     libklu-2.3.5               |   ss783_hfbdfdfc         127 KB  conda-forge
#     liblapack-3.9.0            |26_linux64_openblas          16 KB  conda-forge
#     libldl-3.3.2               |   ss783_h2377355          22 KB  conda-forge
#     libopenblas-0.3.28         |pthreads_h94d23a6_1         5.3 MB  conda-forge
#     libparu-1.0.0              |   ss783_h8814b27          87 KB  conda-forge
#     librbio-4.3.4              |   ss783_h2377355          45 KB  conda-forge
#     libspex-3.2.1              |   ss783_h5a7e440          76 KB  conda-forge
#     libspqr-4.3.4              |   ss783_hae1ff0d         197 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-ng-14.2.0        |       h4852527_1          53 KB  conda-forge
#     libsuitesparseconfig-7.8.3 |   ss783_h83006af          40 KB  conda-forge
#     libumfpack-6.3.5           |   ss783_hd4f9ce1         396 KB  conda-forge
#     llvm-openmp-19.1.7         |       h024ca30_0         3.0 MB  conda-forge
#     metis-5.1.0                |    hd0bcaf9_1007         3.7 MB  conda-forge
#     mpfr-4.2.1                 |       h90cbb55_3         620 KB  conda-forge
#     numpy-2.2.2                |  py310hefbff90_0         7.6 MB  conda-forge
#     openssl-3.4.0              |       h7b32b05_1         2.8 MB  conda-forge
#     pyfmi-2.16.2               |  py310hf462985_0         5.2 MB  conda-forge
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     scipy-1.15.1               |  py310hfa6ec8c_0        17.6 MB  conda-forge
#     suitesparse-7.8.3          |   ss783_h36e971b          11 KB  conda-forge
#     sundials-7.1.1             |       ha52427a_0         907 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        57.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   assimulo           conda-forge/linux-64::assimulo-3.6.0-py310hde9f7ad_0
#   fmilib             conda-forge/linux-64::fmilib-2.4.1-hac33072_1
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   libamd             conda-forge/linux-64::libamd-3.3.3-ss783_h889e182
#   libblas            conda-forge/linux-64::libblas-3.9.0-26_linux64_openblas
#   libbtf             conda-forge/linux-64::libbtf-2.3.2-ss783_h2377355
#   libcamd            conda-forge/linux-64::libcamd-3.3.3-ss783_h2377355
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-26_linux64_openblas
#   libccolamd         conda-forge/linux-64::libccolamd-3.3.4-ss783_h2377355
#   libcholmod         conda-forge/linux-64::libcholmod-5.3.0-ss783_h3fa60b6
#   libcolamd          conda-forge/linux-64::libcolamd-3.3.4-ss783_h2377355
#   libcxsparse        conda-forge/linux-64::libcxsparse-4.4.1-ss783_h2377355
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hd5240d6_1
#   libklu             conda-forge/linux-64::libklu-2.3.5-ss783_hfbdfdfc
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-26_linux64_openblas
#   libldl             conda-forge/linux-64::libldl-3.3.2-ss783_h2377355
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.28-pthreads_h94d23a6_1
#   libparu            conda-forge/linux-64::libparu-1.0.0-ss783_h8814b27
#   librbio            conda-forge/linux-64::librbio-4.3.4-ss783_h2377355
#   libspex            conda-forge/linux-64::libspex-3.2.1-ss783_h5a7e440
#   libspqr            conda-forge/linux-64::libspqr-4.3.4-ss783_hae1ff0d
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libsuitesparsecon~ conda-forge/linux-64::libsuitesparseconfig-7.8.3-ss783_h83006af
#   libumfpack         conda-forge/linux-64::libumfpack-6.3.5-ss783_hd4f9ce1
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-19.1.7-h024ca30_0
#   metis              conda-forge/linux-64::metis-5.1.0-hd0bcaf9_1007
#   mpfr               conda-forge/linux-64::mpfr-4.2.1-h90cbb55_3
#   numpy              conda-forge/linux-64::numpy-2.2.2-py310hefbff90_0
#   pyfmi              conda-forge/linux-64::pyfmi-2.16.2-py310hf462985_0
#   python_abi         conda-forge/linux-64::python_abi-3.10-2_cp310
#   scipy              conda-forge/linux-64::scipy-1.15.1-py310hfa6ec8c_0
#   suitesparse        conda-forge/linux-64::suitesparse-7.8.3-ss783_h36e971b
#   sundials           conda-forge/linux-64::sundials-7.1.1-ha52427a_0
#
# The following packages will be REMOVED:
#
#   libgomp-11.2.0-h1234567_1
#
# The following packages will be UPDATED:
#
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-14.2.0-h69a702a_1
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-14.2.0-h4852527_1
#   openssl              pkgs/main::openssl-3.0.15-h5eee18b_0 --> conda-forge::openssl-3.4.0-h7b32b05_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-5.1-1_gnu --> conda-forge::_openmp_mutex-4.5-2_kmp_llvm
#   ca-certificates    pkgs/main::ca-certificates-2024.12.31~ --> conda-forge::ca-certificates-2024.12.14-hbcca054_0
#   certifi            pkgs/main/linux-64::certifi-2024.12.1~ --> conda-forge/noarch::certifi-2024.12.14-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# suitesparse-7.8.3    | 11 KB     | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-ng-14.2.0     | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# libcamd-3.3.3        | 43 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libcxsparse-4.4.1    | 112 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libparu-1.0.0        | 87 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libamd-3.3.3         | 47 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libcholmod-5.3.0     | 971 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# llvm-openmp-19.1.7   | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# sundials-7.1.1       | 907 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# metis-5.1.0          | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 6 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsuitesparseconfig | 40 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbtf-2.3.2         | 26 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libccolamd-3.3.4     | 40 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# libcxsparse-4.4.1    | 112 KB    | :  14% 0.1434399677820385/1 [00:00<00:00,  1.36it/s]
# libgcc-ng-14.2.0     | 53 KB     | :  30% 0.3026116508440767/1 [00:00<00:00,  2.75it/s]
#
# libcamd-3.3.3        | 43 KB     | :  37% 0.3746455684624531/1 [00:00<00:00,  3.03it/s]
#
#
#
# suitesparse-7.8.3    | 11 KB     | : 100% 1.0/1 [00:00<00:00,  6.86it/s]
#
#
# libcxsparse-4.4.1    | 112 KB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :   1% 0.005578181357625296/1 [00:00<00:29, 29.81s/it]
#
# libcamd-3.3.3        | 43 KB     | : 100% 1.0/1 [00:00<00:00,  3.03it/s]
#
#
#
#
#
#
#
#
# sundials-7.1.1       | 907 KB    | :   2% 0.01763373830085844/1 [00:00<00:11, 11.29s/it]
#
#
#
#
#
#
# libcholmod-5.3.0     | 971 KB    | :   2% 0.016484406520114014/1 [00:00<00:11, 12.12s/it]
#
#
#
#
#
#
#
# suitesparse-7.8.3    | 11 KB     | : 100% 1.0/1 [00:00<00:00,  6.86it/s]
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :  49% 0.4908799594710261/1 [00:00<00:00,  2.22it/s]
#
#
#
#
#
# libamd-3.3.3         | 47 KB     | :  34% 0.3421530750757022/1 [00:00<00:00,  1.12it/s]
#
#
#
#
#
#
#
# llvm-openmp-19.1.7   | 3.0 MB    | :  38% 0.3800046951461654/1 [00:00<00:00,  1.54it/s]
# libgcc-ng-14.2.0     | 53 KB     | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# libgcc-ng-14.2.0     | 53 KB     | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
#
#
#
#
#
#
#
#
#
# metis-5.1.0          | 3.7 MB    | :   0% 0.004175799528999174/1 [00:00<01:22, 83.27s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | :  30% 0.3028185934756492/1 [00:00<00:00,  1.17s/it]
#
#
#
# libparu-1.0.0        | 87 KB     | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
#
#
#
# libparu-1.0.0        | 87 KB     | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 6 KB      | : 100% 1.0/1 [00:00<00:00,  2.67it/s]
#
#
#
#
#
#
#
# llvm-openmp-19.1.7   | 3.0 MB    | :  89% 0.888389354868738/1 [00:00<00:00,  2.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | :  30% 0.30281299671016154/1 [00:00<00:00,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsuitesparseconfig | 40 KB     | :  40% 0.3985986765278318/1 [00:00<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbtf-2.3.2         | 26 KB     | :  62% 0.618637668025978/1 [00:00<00:00,  1.41it/s]
#
#
#
#
#
#
#
#
#
# metis-5.1.0          | 3.7 MB    | :  48% 0.4760411463059059/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | :   2% 0.019303795604097816/1 [00:00<00:23, 24.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libccolamd-3.3.4     | 40 KB     | :  40% 0.397959679378188/1 [00:00<00:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | : 100% 1.0/1 [00:00<00:00,  2.00it/s]
#
#
#
#
#
#
# libcholmod-5.3.0     | 971 KB    | : 100% 1.0/1 [00:00<00:00,  2.25it/s]
#
#
#
#
#
#
# libcholmod-5.3.0     | 971 KB    | : 100% 1.0/1 [00:00<00:00,  2.25it/s]
#
#
#
#
#
# libamd-3.3.3         | 47 KB     | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
#
#
#
#
#
# libamd-3.3.3         | 47 KB     | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
#
#
#
#
#
#
#
#
# sundials-7.1.1       | 907 KB    | : 100% 1.0/1 [00:00<00:00,  1.48it/s]
#
#
#
#
#
#
#
#
# sundials-7.1.1       | 907 KB    | : 100% 1.0/1 [00:00<00:00,  1.48it/s]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | : 100% 1.0/1 [00:01<00:00,  1.03s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | : 100% 1.0/1 [00:01<00:00,  1.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | 6 KB      | : 100% 1.0/1 [00:01<00:00,  2.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsuitesparseconfig | 40 KB     | : 100% 1.0/1 [00:01<00:00,  1.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsuitesparseconfig | 40 KB     | : 100% 1.0/1 [00:01<00:00,  1.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbtf-2.3.2         | 26 KB     | : 100% 1.0/1 [00:01<00:00,  1.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbtf-2.3.2         | 26 KB     | : 100% 1.0/1 [00:01<00:00,  1.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libccolamd-3.3.4     | 40 KB     | : 100% 1.0/1 [00:01<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libccolamd-3.3.4     | 40 KB     | : 100% 1.0/1 [00:01<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | : 100% 1.0/1 [00:01<00:00,  2.00it/s]
#
#
#
#
#
#
#
# llvm-openmp-19.1.7   | 3.0 MB    | : 100% 1.0/1 [00:01<00:00,  2.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
# metis-5.1.0          | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
#
# metis-5.1.0          | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %% [markdown]
# # BPL_TEST2_Fedbatch setup

# %% [markdown]
# Now specific installation and the run simulations. Start with connecting to Github. Then upload the two files:
#
# * FMU - BPL_TEST2_Fedbatch_linux_om_me.fmu
# * Setup-file - BPL_TEST2_Fedbatch_explore.me.py

# %%
# %%bash
# git clone https://github.com/janpeter19/BPL_TEST2_Fedbatch
# Out:
# Cloning into 'BPL_TEST2_Fedbatch'...

# %%
# %cd BPL_TEST2_Fedbatch
# Out:
# /content/BPL_TEST2_Fedbatch

# %%
run -i BPL_TEST2_Fedbatch_explore.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /content/BPL_TEST2_Fedbatch/BPL_TEST2_Fedbatch_explore.py in <module>
#      77 import zipfile
#      78
# ---> 79 from pyfmi import load_fmu
#      80 from pyfmi.fmi import FMUException
#      81
#
# /usr/local/lib/python3.10/site-packages/pyfmi/__init__.py in <module>
#      22
#      23 #Import the model class allowing for users to type e.g.,: from pyfmi import FMUModelME1
# ---> 24 from pyfmi.fmi import load_fmu, FMUModelME1, FMUModelME2
#      25 from pyfmi.fmi import FMUModelCS1, FMUModelCS2
#      26 from pyfmi.fmi_coupled import CoupledFMUModelME2
#
# ModuleNotFoundError: No module named 'pyfmi.fmi'

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [25/2.54, 20/2.54]

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## BPL_TEST2_Fedbatch - demo

# %%
process_diagram()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /content/BPL_TEST2_Fedbatch/BPL_TEST2_Fedbatch_explore.py in <cell line: 0>()
# ----> 1 process_diagram()
#
# NameError: name 'process_diagram' is not defined

# %%
describe('culture'); print(); #describe('liquidphase')                                  # Pump schedule parameter

# %%
# Simulation with default values of the process
newplot(plotType='TimeSeries')
simu(20)

# %%
disp(mode='long')

# %%
# A more typical feed scheme for the culture at hand
newplot(plotType='TimeSeries')
par(t_startExp=4, F_startExp=0.008, mu_feed=0.2, F_max=0.1)
simu(20)

# %%
# Test function simu(mode='cont')
newplot()
simu(15)
simu(5,'cont')

# %%
disp('culture')

# %%
describe('mu')

# %%
describe('parts')

# %%
describe('MSL')

# %%
system_info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /content/BPL_TEST2_Fedbatch/BPL_TEST2_Fedbatch_explore.py in <cell line: 0>()
# ----> 1 system_info()
#
# NameError: name 'system_info' is not defined
